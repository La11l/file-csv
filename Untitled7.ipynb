# %%
import pandas as pd
import matplotlib.pylab as plt

# %%
filename = "C:/Users/Laila/OneDrive/Desktop/distribution_of_schools_classes_students_teachers_by_education_level_and_department_for_2017_-2.csv"

# %%
headers = ["school","addres","managment","sex","famsize","Pstatus","Medu","Fedu","Mjob","Fjob","reason","guardian","traveltime","studytime","failures","schoolsup","famsup","paid","activities","nursery","higher","internet","romantic","famrel","freetime","goout","Dalc","Walc","health","absences","G1","G2","G3"]

# %%
df = pd.read_csv(filename, names = headers)

# %%
df.head()
# Out:
#    school                                             addres      managment  \
# 0     NaN                                                NaN            NaN
# 1     NaN  توزيــــــع المـــدارس حســــب إدارات التعليــ...            NaN
# 2     NaN                                                NaN            NaN
# 3     NaN                                   المنطقة الإدارية  إدارة التعليم
# 4     NaN                                                NaN            NaN
#
#      sex      famsize               Pstatus  Medu      Fedu  \
# 0    NaN          NaN                   NaN   NaN       NaN
# 1    NaN          NaN                   NaN   NaN       NaN
# 2    NaN          NaN                   NaN   NaN       NaN
# 3  الجنس  نوع التعليم  ريــــاض أطفــــــال   NaN       NaN
# 4    NaN          NaN                 حكومي  أهلي  الاجمالي
#
#                  Mjob  Fjob  ...    famrel    freetime goout      Dalc  \
# 0                 NaN   NaN  ...       NaN         NaN   NaN       NaN
# ...

# %%
import numpy as np

# replace "?" to NaN
df.replace("?", np.nan, inplace = True)
df.head(5)
# Out:
#    school                                             addres      managment  \
# 0     NaN                                                NaN            NaN
# 1     NaN  توزيــــــع المـــدارس حســــب إدارات التعليــ...            NaN
# 2     NaN                                                NaN            NaN
# 3     NaN                                   المنطقة الإدارية  إدارة التعليم
# 4     NaN                                                NaN            NaN
#
#      sex      famsize               Pstatus  Medu      Fedu  \
# 0    NaN          NaN                   NaN   NaN       NaN
# 1    NaN          NaN                   NaN   NaN       NaN
# 2    NaN          NaN                   NaN   NaN       NaN
# 3  الجنس  نوع التعليم  ريــــاض أطفــــــال   NaN       NaN
# 4    NaN          NaN                 حكومي  أهلي  الاجمالي
#
#                  Mjob  Fjob  ...    famrel    freetime goout      Dalc  \
# 0                 NaN   NaN  ...       NaN         NaN   NaN       NaN
# ...

# %%
df.drop('addres',axis=1,inplace= True)
df.head(2)
# Out:
#    school managment  sex famsize Pstatus Medu Fedu Mjob Fjob reason  ...  \
# 0     NaN       NaN  NaN     NaN     NaN  NaN  NaN  NaN  NaN    NaN  ...
# 1     NaN       NaN  NaN     NaN     NaN  NaN  NaN  NaN  NaN    NaN  ...
#
#   famrel freetime goout Dalc Walc health absences  G1  G2  G3
# 0    NaN      NaN   NaN  NaN  NaN    NaN      NaN NaN NaN NaN
# 1    NaN      NaN   NaN  NaN  NaN    NaN      NaN NaN NaN NaN
#
# [2 rows x 32 columns]

# %%
df_ = df.replace('[^\d.]','',regex=True).astype(str)
df_
# Out:
#     school managment  sex famsize Pstatus    Medu    Fedu     Mjob    Fjob  \
# 0      nan       nan  nan     nan     nan     nan     nan      nan     nan
# 1      nan       nan  nan     nan     nan     nan     nan      nan     nan
# 2      nan       nan  nan     nan     nan     nan     nan      nan     nan
# 3      nan                                    nan     nan              nan
# 4      nan       nan  nan     nan
# ..     ...       ...  ...     ...     ...     ...     ...      ...     ...
# 616    nan       nan  nan             0.0     0.0     0.0    527.0    69.0
# 617    nan       nan  nan             0.0     0.0     0.0      2.0     0.0
# 618    nan       nan  nan          2132.0  1272.0  3404.0   6322.0   780.0
# 619    nan       nan  nan     nan  2132.0  1272.0  3404.0  12647.0  1390.0
# 620    nan       nan  nan     nan             nan  3404.0              nan
#
#       reason  ...  famrel freetime goout    Dalc     Walc health absences  \
# ...

# %%
df.tail(5)
# Out:
#      school managment  sex     famsize            Pstatus    Medu    Fedu  \
# 616     NaN       NaN  NaN       تحفيظ                0.0     0.0     0.0
# 617     NaN       NaN  NaN  تربية خاصة                0.0     0.0     0.0
# 618     NaN       NaN  NaN        جملة             2132.0  1272.0  3404.0
# 619     NaN       NaN  NaN         NaN             2132.0  1272.0  3404.0
# 620     NaN       NaN  NaN         NaN  اجمالي رياض أطفال     NaN  3404.0
#
#                Mjob    Fjob   reason  ...  famrel           freetime goout  \
# 616           527.0    69.0    596.0  ...     0.0                0.0   5.0
# 617             2.0     0.0      2.0  ...     0.0             1011.0  39.0
# 618          6322.0   780.0   7102.0  ...  1158.0             1011.0  44.0
# 619         12647.0  1390.0  14037.0  ...  1799.0             2713.0  64.0
# 620  اجمالي ابتدائي     NaN  14037.0  ...  1799.0  اجمالي تربية خاصة   NaN
#
#        Dalc     Walc health absences  G1  G2  G3
# ...

# %%
df.isnull()
# Out:
#      school  managment    sex  famsize  Pstatus   Medu   Fedu   Mjob   Fjob  \
# 0      True       True   True     True     True   True   True   True   True
# 1      True       True   True     True     True   True   True   True   True
# 2      True       True   True     True     True   True   True   True   True
# 3      True      False  False    False    False   True   True  False   True
# 4      True       True   True     True    False  False  False  False  False
# ..      ...        ...    ...      ...      ...    ...    ...    ...    ...
# 616    True       True   True    False    False  False  False  False  False
# 617    True       True   True    False    False  False  False  False  False
# 618    True       True   True    False    False  False  False  False  False
# 619    True       True   True     True    False  False  False  False  False
# 620    True       True   True     True    False   True  False  False   True
#
# ...

# %%
df.isnull().sum()
# Out:
# school        621
# managment     548
# sex           500
# famsize        20
# Pstatus         4
# Medu            6
# Fedu            5
# Mjob            4
# Fjob            6
# reason          5
# guardian        4
# traveltime      6
# studytime       6
# failures        5
# schoolsup       3
# famsup          6
# paid            5
# activities      6
# nursery         6
# higher          5
# internet        4
# romantic        6
# famrel          5
# freetime        4
# goout           6
# Dalc            5
# Walc            5
# health        621
# absences      620
# G1            621
# G2            621
# G3            621
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 4910

# %%
df1 = df.fillna(value=5)
df1
# Out:
#      school      managment    sex      famsize               Pstatus    Medu  \
# 0       5.0              5      5            5                     5       5
# 1       5.0              5      5            5                     5       5
# 2       5.0              5      5            5                     5       5
# 3       5.0  إدارة التعليم  الجنس  نوع التعليم  ريــــاض أطفــــــال       5
# 4       5.0              5      5            5                 حكومي    أهلي
# ..      ...            ...    ...          ...                   ...     ...
# 616     5.0              5      5        تحفيظ                   0.0     0.0
# 617     5.0              5      5   تربية خاصة                   0.0     0.0
# 618     5.0              5      5         جملة                2132.0  1272.0
# 619     5.0              5      5            5                2132.0  1272.0
# 620     5.0              5      5            5     اجمالي رياض أطفال       5
#
# ...

# %%
df1.isnull().sum().sum()
# Out:
# 0

# %%
df
# Out:
#      school      managment    sex      famsize               Pstatus    Medu  \
# 0       5.0              5      5            5                     5       5
# 1       5.0              5      5            5                     5       5
# 2       5.0              5      5            5                     5       5
# 3       5.0  إدارة التعليم  الجنس  نوع التعليم  ريــــاض أطفــــــال       5
# 4       5.0              5      5            5                 حكومي    أهلي
# ..      ...            ...    ...          ...                   ...     ...
# 616     5.0              5      5        تحفيظ                   0.0     0.0
# 617     5.0              5      5   تربية خاصة                   0.0     0.0
# 618     5.0              5      5         جملة                2132.0  1272.0
# 619     5.0              5      5            5                2132.0  1272.0
# 620     5.0              5      5            5     اجمالي رياض أطفال       5
#
# ...

# %%
df1.fillna({"school":"not available","G1":"-1"})
# Out:
#      school      managment    sex      famsize               Pstatus    Medu  \
# 0       5.0              5      5            5                     5       5
# 1       5.0              5      5            5                     5       5
# 2       5.0              5      5            5                     5       5
# 3       5.0  إدارة التعليم  الجنس  نوع التعليم  ريــــاض أطفــــــال       5
# 4       5.0              5      5            5                 حكومي    أهلي
# ..      ...            ...    ...          ...                   ...     ...
# 616     5.0              5      5        تحفيظ                   0.0     0.0
# 617     5.0              5      5   تربية خاصة                   0.0     0.0
# 618     5.0              5      5         جملة                2132.0  1272.0
# 619     5.0              5      5            5                2132.0  1272.0
# 620     5.0              5      5            5     اجمالي رياض أطفال       5
#
# ...
